# %% [markdown]
# # World model blueprint Launchable
#
# This notebook runs the pilot workflow for the world model blueprint. Configure `deploy/.env`, set `WMB_AGENT_OBJECTIVE`, and run the launch cell.

# %%
from pathlib import Path
import subprocess

root = Path.cwd()
subprocess.run([str(root / "scripts" / "wmb-agent-launchable")], check=True)
